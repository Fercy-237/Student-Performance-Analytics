# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\acer

# %%
import pandas as pd

df = pd.read_csv("student_marks.csv")
df.head()
# Out:
#    Student_ID Student_Name Department  Maths  Science  English  Total  \
# 0         101         Arun        BCA     85       78       90    253
# 1         102        Priya        BCA     70       65       80    215
# 2         103         John        BSc     45       50       40    135
# 3         104        Meena       BCom     90       92       88    270
# 4         105        Rahul        BCA     30       25       40     95
#
#    Average Grade Result
# 0    84.33     A   Pass
# 1    71.67     B   Pass
# 2    45.00     C   Pass
# 3    90.00     A   Pass
# 4    31.67     F   Fail

# %%
topper = df.loc[df['Total'].idxmax()]
topper
# Out:
# Student_ID        109
# Student_Name    Nisha
# Department        BCA
# Maths              95
# Science            93
# English            97
# Total             285
# Average          95.0
# Grade               A
# Result           Pass
# Name: 8, dtype: object

# %%
df[df['Result'] == 'Fail']
# Out:
#    Student_ID Student_Name Department  Maths  Science  English  Total  \
# 4         105        Rahul        BCA     30       25       40     95
# 9         110      Vignesh        BSc     40       35       45    120
#
#    Average Grade Result
# 4    31.67     F   Fail
# 9    40.00     F   Fail

# %%
df[['Maths','Science','English']].mean()
# Out:
# Maths      68.933333
# Science    69.466667
# English    71.266667
# dtype: float64

# %%
df['Average'].mean()
# Out:
# np.float64(69.88866666666668)

# %%
df['Grade'].value_counts()
# Out:
# Grade
# A    6
# B    4
# C    3
# F    2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df[['Maths','Science','English']].mean().plot(kind='bar')

plt.title('Subject Wise Performance')
plt.xlabel('Subjects')
plt.ylabel('Average Marks')

plt.show()

# %%
df['Result'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.title('Pass vs Fail')
plt.show()
